# %% [markdown]
# ## Pands

# %%
import pandas as pd
# %matplotlib inline

# %%
# Series - 1D
car_company=pd.Series(['BMW','Toyota','Honda'])
car_prices=pd.Series([23845,17945,135925])

# %% [markdown]
# # DataFrame - 2D

# %%
car_df=pd.DataFrame({'car company':car_company,'price':car_prices})

car_df
# Out:
#   car company   price
# 0         BMW   23845
# 1      Toyota   17945
# 2       Honda  135925

# %%
# Import data
cars_sales=pd.read_csv('./car-sales-extended-missing-data.csv')
cars_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
cars_sales['Make'].head()
# Out:
# 0     Honda
# 1       BMW
# 2     Honda
# 3    Toyota
# 4    Nissan
# Name: Make, dtype: object

# %% [markdown]
# ## mapping to varible

# %%
cars_sales.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
cars_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# # View and select data

# %%
# head() - first 5 rows

cars_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
# tail() - last 5 rows

cars_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0

# %% [markdown]
# ## .loc & .iloc

# %%
# loc -> locate index
# the Big 3  😅
Big3=pd.Series(['Naruto','One Piece','Dragon Ball Z'],index=[1,2,3])
NewBig3=pd.Series(['Demons slayer','AOT','jujutsu kaisan'],index=[1,2,3])

Animea=pd.DataFrame({'Big3':Big3,'NewBig3':NewBig3})

Animea.loc[[1,2]]
# Out:
#         Big3        NewBig3
# 1     Naruto  Demons slayer
# 2  One Piece            AOT

# %%
# iloc -> locate position

Big3.iloc[1]

cars_sales.iloc[[1,2],1] # 1st and 2nd row, 1st column
# Out:
# 1     Blue
# 2    White
# Name: Colour, dtype: object

# %% [markdown]
# ## Selecting coloums

# %%
cars_sales.Colour.head()
# Out:
# 0    White
# 1     Blue
# 2    White
# 3    White
# 4     Blue
# Name: Colour, dtype: object

# %%
car_df[car_df['car company']=='BMW'] # filter

# Export data
# Out:
#   car company  price
# 0         BMW  23845

# %%
cars_sales[cars_sales["Odometer (KM)"]>100000]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 1       BMW   Blue       192714.0    5.0  19943.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# 6    Toyota   Blue       163453.0    4.0   8473.0
# 8       NaN  White       130538.0    4.0   9374.0
# ..      ...    ...            ...    ...      ...
# 993  Nissan  Black       162523.0    4.0   4696.0
# 994     BMW   Blue       163322.0    3.0  31666.0
# 996     NaN  White       155144.0    3.0   5716.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [597 rows x 5 columns]

# %%
pd.crosstab(cars_sales['Make'],cars_sales['Doors'])
# Out:
# Doors   3.0  4.0  5.0
# Make
# BMW      21    0   72
# Honda     0  276    0
# Nissan   38  137    0
# Toyota    0  359    0

# %%
cars_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     127491.439560  4.548387  26902.440860
# Honda   125233.374101  4.000000  14618.661922
# Nissan  136809.029070  3.782857  13664.502857
# Toyota  135942.582873  4.000000  15715.257062

# %% [markdown]
# # Visualisation of data

# %%
 # plot
car_df['price'].plot()
# Out:
# <AxesSubplot:>

# %%
car_df['price'].hist()
# Out:
# <AxesSubplot:>

# %%
car_df['price'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Coverting Object to int

# %%
car_df['new price']=[str(price)+'$' for price in car_df['price']]


car_df['new price']
# Out:
# 0     23845$
# 1     17945$
# 2    135925$
# Name: new price, dtype: object

# %%
# delte column
car_df.drop('new price',axis=1,inplace=True)

# %%
car_df['new price']=car_df['new price'].str.replace('[\$\,\.]','').astype(int)

car_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Volumes/Project/software/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /Volumes/Project/software/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Volumes/Project/software/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/hn/5r0zs8c94dz3z1pnjkkmycfm0000gn/T/ipykernel_85515/928147427.py in <module>
# ----> 1 car_df['new price']=car_df['new price'].str.replace('[\$\,\.]','').astype(int)
#       2
#       3 car_df
#
# /Volumes/Project/software/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /Volumes/Project/software/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'new price'

# %%
car_df['new price']= [price*2 for price in car_df['price']]
car_df
# Out:
#   car company   price  new price
# 0         BMW   23845      47690
# 1      Toyota   17945      35890
# 2       Honda  135925     271850

# %% [markdown]
# # Manipulate data

# %%
Animea['Big3']= Animea['Big3'].apply(lambda x:x.upper())

Animea
# Out:
#             Big3         NewBig3
# 1         NARUTO   Demons slayer
# 2      ONE PIECE             AOT
# 3  DRAGON BALL Z  jujutsu kaisan

# %% [markdown]
# ## Missing values

# %%
cars_sales_missing= pd.read_csv("./car-sales-extended-missing-data.csv")

cars_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_df['year']=pd.Series([2018,2019])
# fillna(x) - fill missing data with x [inplace=True] - save the change
car_df.fillna(2023,inplace=True)

car_df
# Out:
#   car company   price    year
# 0         BMW   23845  2018.0
# 1      Toyota   17945  2019.0
# 2       Honda  135925  2023.0

# %%
# drop missing column

cars_sales_missing.dropna(inplace=True) # drop missing data
cars_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %% [markdown]
# ## Coloumn from series

# %%
seats_coloum=pd.Series([5,5,5,5,5])

cars_sales_missing['Seats']=seats_coloum
cars_sales_missing # add new column only 5 rows will have data rest will be NaN
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0    5.0
# 1       BMW   Blue       192714.0    5.0  19943.0    5.0
# 2     Honda  White        84714.0    4.0  28343.0    5.0
# 3    Toyota  White       154365.0    4.0  13434.0    5.0
# 4    Nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0    NaN
# 995  Toyota  Black        35820.0    4.0  32042.0    NaN
# 997  Nissan   Blue        66604.0    4.0  31570.0    NaN
# 998   Honda  White       215883.0    4.0   4001.0    NaN
# 999  Toyota   Blue       248360.0    4.0  12732.0    NaN
#
# [773 rows x 6 columns]

# %%
# now let fill the NaN with 5

cars_sales_missing['Seats'].fillna(5,inplace=True)

# %%
cars_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0    5.0
# 1       BMW   Blue       192714.0    5.0  19943.0    5.0
# 2     Honda  White        84714.0    4.0  28343.0    5.0
# 3    Toyota  White       154365.0    4.0  13434.0    5.0
# 4    Nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0    5.0
# 995  Toyota  Black        35820.0    4.0  32042.0    5.0
# 997  Nissan   Blue        66604.0    4.0  31570.0    5.0
# 998   Honda  White       215883.0    4.0   4001.0    5.0
# 999  Toyota   Blue       248360.0    4.0  12732.0    5.0
#
# [773 rows x 6 columns]

# %%
fuel_economy=pd.Series([7.5,9.2,5.0,9.6,8.7])



cars_sales['Fuel per 100KM']=fuel_economy

# fill missing data with mean
cars_sales['Fuel per 100KM'].fillna(cars_sales['Fuel per 100KM'].mean(),inplace=True)
cars_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0   Honda  White        35431.0    4.0  15323.0             7.5
# 1     BMW   Blue       192714.0    5.0  19943.0             9.2
# 2   Honda  White        84714.0    4.0  28343.0             5.0
# 3  Toyota  White       154365.0    4.0  13434.0             9.6
# 4  Nissan   Blue       181577.0    3.0  14043.0             8.7
# 5   Honda    Red        42652.0    4.0  23883.0             8.0
# 6  Toyota   Blue       163453.0    4.0   8473.0             8.0
# 7   Honda  White            NaN    4.0  20306.0             8.0
# 8     NaN  White       130538.0    4.0   9374.0             8.0
# 9   Honda   Blue        51029.0    4.0  26683.0             8.0
#
#    Total fuel used (L)
# 0             2657.325
# 1            17729.688
# 2             4235.700
# 3            14819.040
# 4            15797.199
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN

# %%
fuelUsed=cars_sales['Odometer (KM)']/100 * cars_sales['Fuel per 100KM']

cars_sales['Total fuel used (L)']=fuelUsed

# %%
cars_sales.dropna(inplace=True)
cars_sales.head(10)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0    Honda  White        35431.0    4.0  15323.0             7.5
# 1      BMW   Blue       192714.0    5.0  19943.0             9.2
# 2    Honda  White        84714.0    4.0  28343.0             5.0
# 3   Toyota  White       154365.0    4.0  13434.0             9.6
# 4   Nissan   Blue       181577.0    3.0  14043.0             8.7
# 5    Honda    Red        42652.0    4.0  23883.0             8.0
# 6   Toyota   Blue       163453.0    4.0   8473.0             8.0
# 9    Honda   Blue        51029.0    4.0  26683.0             8.0
# 10  Nissan  White       167421.0    4.0  16259.0             8.0
# 11  Nissan  Green        17119.0    4.0   6160.0             8.0
#
#     Total fuel used (L)
# 0              2657.325
# 1             17729.688
# 2              4235.700
# 3             14819.040
# 4             15797.199
# 5              3412.160
# 6             13076.240
# 9              4082.320
# 10            13393.680
# 11             1369.520

# %% [markdown]
# ## Shuffling the data

# %%
cars_shuffled_data=cars_sales.sample(frac=0.2)

cars_shuffled_data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 67   Toyota  Black        93054.0    4.0   6652.0             8.0
# 374  Toyota   Blue       198570.0    4.0  17284.0             8.0
# 989  Toyota    Red        41735.0    4.0  13928.0             8.0
# 706   Honda  Black       151414.0    4.0  12186.0             8.0
# 80    Honda  Black       149879.0    4.0   8200.0             8.0
# ..      ...    ...            ...    ...      ...             ...
# 575   Honda   Blue       142403.0    4.0   6803.0             8.0
# 443  Toyota   Blue        71306.0    4.0  23747.0             8.0
# 304  Toyota  White        55828.0    4.0  23311.0             8.0
# 861     BMW  White        69066.0    5.0  22784.0             8.0
# 495     BMW  Black       181572.0    5.0  25763.0             8.0
#
#      Total fuel used (L)
# 67               7444.32
# 374             15885.60
# 989              3338.80
# 706             12113.12
# 80              11990.32
# ..                   ...
# 575             11392.24
# 443              5704.48
# 304              4466.24
# 861              5525.28
# 495             14525.76
#
# [155 rows x 7 columns]

# %%
cars_sales.loc[cars_sales['Make']=='Toyota','Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>
