# %%
import pandas as pd

house=pd.read_csv('./data/kc_house_data.csv')
titanic=pd.read_csv('./data/titanic.csv')
netflix=pd.read_csv('./data/netflix_titles.csv',sep='|',index_col=0)
btc=pd.read_csv('./data/coin_Bitcoin.csv')
countires=pd.read_csv('./data/world-happiness-report-2021.csv')

# %%
countires.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
countires.set_index('Country name',inplace=True)

# %%
btc.drop(labels="Symbol",axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# if we want to drop multiple columns
btc.drop(columns=["Name","SNo"],axis='columns',inplace=True)

# %% [markdown]
# ## Deleting the Rows

# %%
countires.drop(labels=["Denmark","Finland","Norway","India"],axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# ...

# %%
btc.sort_index(ascending=False,axis=0,inplace=True)

# %%
btc.drop(2990)
# Out:
#      Symbol          High           Low          Open         Close  \
# 2989    BTC  35284.344430  33213.661034  35284.344430  33746.002456
# 2988    BTC  35937.567147  34396.477458  34665.564866  35287.779766
# 2987    BTC  34909.259899  33402.696536  33854.421362  34668.548402
# 2986    BTC  33939.588699  32770.680780  33549.600177  33897.048590
# 2985    BTC  35035.982712  32883.781226  35035.982712  33572.117653
# ...     ...           ...           ...           ...           ...
# 4       BTC    108.127998     79.099998    106.250000     97.750000
# 3       BTC    125.599998     92.281898    116.379997    105.209999
# 2       BTC    139.889999    107.720001    139.000000    116.989998
# 1       BTC    146.929993    134.050003    144.000000    139.000000
# 0       BTC    147.488007    134.000000    134.444000    144.539993
#
#             Volume     Marketcap
# 2989  2.672155e+10  6.326962e+11
# 2988  2.492431e+10  6.615748e+11
# 2987  2.438396e+10  6.499397e+11
# ...

# %%
# drop the first 5 rows in countires

countires.drop(countires.index[:5],inplace=True)

# %%
countires
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Norway                                 0.035         7.462         7.323
# Sweden                                 0.036         7.433         7.293
# Luxembourg                             0.037         7.396         7.252
# ...

# %% [markdown]
# # Adding static columns

# %%
titanic["species"]="human"

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## insert a new column at a specific location

# %%
house.insert(0,"couty","King Country")
house
# Out:
#               couty          id             date     price  bedrooms  \
# 0      King Country  7129300520  20141013T000000  221900.0         3
# 1      King Country  6414100192  20141209T000000  538000.0         3
# 2      King Country  5631500400  20150225T000000  180000.0         2
# 3      King Country  2487200875  20141209T000000  604000.0         4
# 4      King Country  1954400510  20150218T000000  510000.0         3
# ...             ...         ...              ...       ...       ...
# 21608  King Country   263000018  20140521T000000  360000.0         3
# 21609  King Country  6600060120  20150223T000000  400000.0         4
# 21610  King Country  1523300141  20140623T000000  402101.0         2
# 21611  King Country   291310100  20150116T000000  400000.0         3
# 21612  King Country  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# ...

# %% [markdown]
# ## Creating new Dynamic Columns

# %%
titanic.drop(columns="species",inplace=True)

# %%
titanic.insert(2,"Relatives",titanic["sibsp"]+titanic["parch"])

# %%
titanic
# Out:
#       pclass  survived  Relatives  \
# 0          1         1          0
# 1          1         1          3
# 2          1         0          3
# 3          1         0          3
# 4          1         0          3
# ...      ...       ...        ...
# 1304       3         0          1
# 1305       3         0          1
# 1306       3         0          0
# 1307       3         0          0
# 1308       3         0          0
#
#                                                  name     sex     age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female      29      0
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...                                               ...     ...     ...    ...
# ...

# %%
titanic[titanic["survived"]==1].sort_values(by="Relatives",ascending=False)
# Out:
#      pclass  survived  Relatives  \
# 641       3         1          6
# 625       3         1          6
# 646       3         1          6
# 643       3         1          6
# 111       1         1          5
# ..      ...       ...        ...
# 597       2         1          0
# 598       2         1          0
# 604       3         1          0
# 605       3         1          0
# 0         1         1          0
#
#                                                   name     sex age  sibsp  \
# 641                  Asplund, Master. Edvin Rojj Felix    male   3      4
# 625                    Andersson, Miss. Erna Alexandra  female  17      4
# 646  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38      1
# 643                     Asplund, Miss. Lillian Gertrud  female   5      4
# 111                     Fortune, Miss. Alice Elizabeth  female  24      3
# ..                                                 ...     ...  ..    ...
# ...

# %%
# get the pople who travel alone and survived
solo_survived=titanic[(titanic["survived"]==1) & (titanic["Relatives"]==0)]

solo_survived
# Out:
#       pclass  survived  Relatives  \
# 0          1         1          0
# 5          1         1          0
# 12         1         1          0
# 13         1         1          0
# 14         1         1          0
# ...      ...       ...        ...
# 1254       3         1          0
# 1260       3         1          0
# 1261       3         1          0
# 1277       3         1          0
# 1286       3         1          0
#
#                                                  name     sex age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29      0
# 5                                 Anderson, Mr. Harry    male  48      0
# 12                      Aubart, Mme. Leontine Pauline  female  24      0
# 13                       Barber, Miss. Ellen 'Nellie'  female  26      0
# 14               Barkworth, Mr. Algernon Henry Wilson    male  80      0
# ...                                               ...     ...  ..    ...
# ...

# %%
house["price_sqft"]=house["price"]/house["sqft_living"]

# %%
house
# Out:
#               couty          id             date     price  bedrooms  \
# 0      King Country  7129300520  20141013T000000  221900.0         3
# 1      King Country  6414100192  20141209T000000  538000.0         3
# 2      King Country  5631500400  20150225T000000  180000.0         2
# 3      King Country  2487200875  20141209T000000  604000.0         4
# 4      King Country  1954400510  20150218T000000  510000.0         3
# ...             ...         ...              ...       ...       ...
# 21608  King Country   263000018  20140521T000000  360000.0         3
# 21609  King Country  6600060120  20150223T000000  400000.0         4
# 21610  King Country  1523300141  20140623T000000  402101.0         2
# 21611  King Country   291310100  20150116T000000  400000.0         3
# 21612  King Country  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
# gettop 10 most expensive houses

house.sort_values(by="price_sqft",ascending=False).head(50)["zipcode"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # Lets find the largest bitcoing change

# %%
btc.set_index("Date",inplace=True)

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc['Price Change']=btc['Close']-btc['Open']

# %%
btc.sort_values(by="Price Change",ascending=False)
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-02-08 23:59:59  2843  Bitcoin    BTC  46203.931437  38076.322807
# 2021-04-26 23:59:59  2920  Bitcoin    BTC  54288.002155  48852.796843
# 2021-03-01 23:59:59  2864  Bitcoin    BTC  49784.015290  45115.093115
# 2021-02-19 23:59:59  2854  Bitcoin    BTC  56113.650547  50937.275722
# 2021-04-30 23:59:59  2924  Bitcoin    BTC  57900.719988  53129.600877
# ...                   ...      ...    ...           ...           ...
# 2021-04-18 23:59:59  2912  Bitcoin    BTC  61057.456509  52829.535926
# 2021-01-21 23:59:59  2825  Bitcoin    BTC  35552.679497  30250.749639
# 2021-02-23 23:59:59  2858  Bitcoin    BTC  54204.929756  45290.590268
# 2021-05-19 23:59:59  2943  Bitcoin    BTC  43546.116485  30681.496912
# 2021-05-12 23:59:59  2936  Bitcoin    BTC  57939.362415  49150.533875
#
#                              Open         Close        Volume     Marketcap  \
# Date
# ...
